# %%
#Import some libraries
import numpy as np
import matplotlib as plt
import scipy as sp
from scipy import *

# %% [markdown]
# *How do I make this itallic*
#
# #Is this how I make it bold#
#
# Obviously not
#
# **Anyway, let me try to commit this, and see how it works**
#
# Omg thats how I make it bold
